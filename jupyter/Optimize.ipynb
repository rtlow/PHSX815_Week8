# %%
import numpy as np
from scipy import optimize
import scipy.special as special

# %%
# N-dimensional Airy disk function
# negative so that it has a large minimum at the origin

def negAiryND(x):
    
    q = np.sqrt(np.sum(x**2))
    
    fx = -(2 * special.j1(q)/q)**2
    
    return fx

# %%
# consider D dimensions

D = 10

# choosing a random starting point
# explicitly away from the origin

x0 = np.random.normal(7, 3, size=D)

optimize.minimize(negAiryND, x0)
# Out:
#       fun: -8.894025847876701e-05
#  hess_inv: array([[ 218.85454621,  559.9283739 ,  308.09075131,  365.71043622,
#          551.2434626 ,  493.54962643,  159.97898226,  205.85221797,
#          289.31473622,  294.42698451],
#        [ 559.9283739 , 1440.12435775,  791.85289632,  939.94664528,
#         1416.80245376, 1268.51812172,  411.17696624,  529.08006593,
#          743.59490134,  756.7343695 ],
#        [ 308.09075131,  791.85289632,  436.70314548,  517.18912924,
#          779.57066078,  697.97981203,  226.2429024 ,  291.11701177,
#          409.15003151,  416.37979304],
#        [ 365.71043622,  939.94664528,  517.18912924,  614.91476783,
#          925.36736402,  828.51724839,  268.55525581,  345.56223746,
#          485.67000426,  494.25188876],
#        [ 551.2434626 , 1416.80245376,  779.57066078,  925.36736402,
#         1395.82677933, 1248.84244909,  404.79930144,  520.87363514,
#          732.06118369,  744.99684879],
#        [ 493.54962643, 1268.51812172,  697.97981203,  828.51724839,
#         1248.84244909, 1119.13702302,  362.43249591,  466.35834343,
#          655.44273675,  667.02453882],
#        [ 159.97898226,  411.17696624,  226.2429024 ,  268.55525581,
#          404.79930144,  362.43249591,  118.47872702,  151.16521045,
#          212.45495151,  216.20907229],
#        [ 205.85221797,  529.08006593,  291.11701177,  345.56223746,
#          520.87363514,  466.35834343,  151.16521045,  195.51113773,
#          273.37542951,  278.20602712],
#        [ 289.31473622,  743.59490134,  409.15003151,  485.67000426,
#          732.06118369,  655.44273675,  212.45495151,  273.37542951,
#          385.21514744,  391.00430466],
#        [ 294.42698451,  756.7343695 ,  416.37979304,  494.25188876,
#          744.99684879,  667.02453882,  216.20907229,  278.20602712,
#          391.00430466,  398.91342763]])
#       jac: array([5.43401256e-07, 1.39665190e-06, 7.68486643e-07, 9.12206815e-07,
#        1.37499228e-06, 1.23108293e-06, 3.99044438e-07, 5.13464329e-07,
#        7.21650395e-07, 7.34403329e-07])
#   message: 'Optimization terminated successfully.'
#      nfev: 108
#       nit: 3
#      njev: 9
#    status: 0
#   success: True
#         x: array([ 5.6814611 , 14.60245507,  8.03474602,  9.5374116 , 14.37595613,
#        12.87134976,  4.17211293,  5.36844502,  7.54508131,  7.6784061 ])
